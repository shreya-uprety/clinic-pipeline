# %%
import json

import importlib
import bucket_ops
import my_agents
import pandas as pd
import schedule_manager



importlib.reload(bucket_ops)

gcs = bucket_ops.GCSBucketManager(bucket_name="clinic_sim")

# %%
schedule_ops = schedule_manager.ScheduleCSVManager(gcs_manager=gcs, csv_blob_path="clinic_data/nurse_schedule.csv")

# %%
data = schedule_ops.get_all()

# %%
data
# Out:
# [{'id': 'N0001',
#   'patient': 'P0001',
#   'date': '2026-01-22',
#   'time': '8:00',
#   'status': 'done'},
#  {'id': 'N0001',
#   'patient': '',
#   'date': '2026-01-22',
#   'time': '8:30',
#   'status': ''},
#  {'id': 'N0001',
#   'patient': 'P0002',
#   'date': '2026-01-22',
#   'time': '9:00',
#   'status': 'done'},
#  {'id': 'N0001',
#   'patient': 'P0003',
#   'date': '2026-01-22',
#   'time': '9:30',
#   'status': 'current'},
#  {'id': 'N0001',
#   'patient': '',
#   'date': '2026-01-22',
#   'time': '10:00',
#   'status': ''},
#  {'id': 'N0001',
#   'patient': 'P0004',
#   'date': '2026-01-22',
#   'time': '10:30',
#   'status': ''},
#  {'id': 'N0001',
#   'patient': 'P0005',
#   'date': '2026-01-22',
#   'time': '11:00',
#   'status': ''},
#  {'id': 'N0001',
#   'patient': 'P0006',
#   'date': '2026-01-22',
#   'time': '11:30',
#   'status': ''},
#  {'id': 'N0001',
#   'patient': '',
#   'date': '2026-01-22',
#   'time': '12:00',
#   'status': 'break'},
#  {'id': 'N0001',
#   'patient': '',
#   'date': '2026-01-22',
#   'time': '12:30',
#   'status': 'break'},
#  {'id': 'N0001',
#   'patient': 'P0007',
#   'date': '2026-01-22',
#   'time': '13:00',
#   'status': ''},
#  {'id': 'N0001',
#   'patient': 'P0008',
#   'date': '2026-01-22',
#   'time': '13:30',
#   'status': ''},
#  {'id': 'N0001',
#   'patient': 'P0009',
#   'date': '2026-01-22',
#   'time': '14:00',
#   'status': ''},
#  {'id': 'N0001',
#   'patient': 'P0010',
#   'date': '2026-01-22',
#   'time': '14:30',
#   'status': ''},
#  {'id': 'N0001',
#   'patient': 'P0011',
#   'date': '2026-01-22',
#   'time': '15:00',
#   'status': ''},
#  {'id': 'N0001',
#   'patient': '',
#   'date': '2026-01-22',
#   'time': '15:30',
#   'status': ''},
#  {'id': 'N0001',
#   'patient': 'P0012',
#   'date': '2026-01-22',
#   'time': '16:00',
#   'status': ''},
#  {'id': 'N0001',
#   'patient': 'P0013',
#   'date': '2026-01-22',
#   'time': '16:30',
#   'status': ''},
#  {'id': 'N0001',
#   'patient': 'P0014',
#   'date': '2026-01-22',
#   'time': '17:00',
#   'status': ''}]

# %%
csv_data = gcs.read_file_as_string(f"clinic_data/nurse_schedule.csv")

# %%
file_list = gcs.list_files("patient_data/P0001/raw_data/")

# %%
file_list
# Out:
# ['patient_data_P0001_raw_data_encounter_report_0_2026-01-19.png',
#  'patient_data_P0001_raw_data_encounter_report_1_2025-10-19.png',
#  'patient_data_P0001_raw_data_encounter_report_2_2025-07-19.png',
#  'patient_data_P0001_raw_data_imaging_report_0_2026-01-19.png',
#  'patient_data_P0001_raw_data_imaging_report_2_2025-07-19.png',
#  'patient_data_P0001_raw_data_lab_report_0_2025-07-19.png',
#  'patient_data_P0001_raw_data_lab_report_1_2025-10-19.png',
#  'patient_data_P0001_raw_data_lab_report_2_2026-01-19.png',
#  'patient_data_P0001_referral_letter.png']

# %%
with open("output/history_data.json", "r", encoding="utf-8") as f:
    data_history = json.load(f)

# %%
gcs.create_file_from_string(
    json.dumps(data_history, indent=4),
    f"patient_data/P0001/pre_consultation_chat.json",
    content_type="application/json"
)
# Out:
# Content uploaded to patient_data/P0001/pre_consultation_chat.json.
# True

# %%
pre_consult_chat_path = f"patient_data/P0001/pre_consultation_chat.json"
content_str = gcs.read_file_as_string(pre_consult_chat_path)
history_data = json.loads(content_str)


# with open("output/history_data.json", "w", encoding="utf-8") as f:
#     json.dump(history_data, f, indent=4)
history_data
# Out:
# {'conversation': [{'sender': 'admin',
#    'message': 'Hello, this is Linda the Hepatology Clinic admin desk. How can I help you today?'},
#   {'sender': 'patient',
#    'message': 'I want to book appointment',
#    'attachments': [],
#    'form_data': None},
#   {'message': 'To book an appointment, please first confirm if you have booked through the NHS App. If so, please provide a screenshot of your booking confirmation.',
#    'action_type': 'TEXT_ONLY',
#    'sender': 'admin'},
#   {'sender': 'patient',
#    'message': 'I dont have any booking',
#    'attachments': [],
#    'form_data': None},
#   {'message': 'No problem. To help us prepare for your visit, please fill out this intake form.',
#    'action_type': 'SEND_FORM',
#    'form_request': {'name': '',
#     'firstName': '',
#     'lastName': '',
#     'dob': '',
#     'age': None,
#     'gender': '',
#     'occupation': '',
#     'maritalStatus': '',
#     'contact': {'phone': '',
#      'email': '',
#      'address': {'street': '', 'city': '', 'state': '', 'zipCode': ''},
#      'emergency': {'name': '', 'relation': '', 'phone': ''}},
#     'complaint': '',
#     'medical_history': [],
#     'allergies': []},
#    'sender': 'admin'},
#   {'sender': 'patient',
#    'message': 'I have completed the intake form.',
#    'attachments': [],
#    'form_data': {'name': 'Arthur Pendelton',
#     'dob': '1970-03-15',
#     'contact': {'phone': '+44 7700 900456',
#      'email': 'arthur.pendelton@email.co.uk',
#      'address': {'street': 'Flat 3B, 27 Ashton Street',
#       'city': 'Manchester',
#       'state': 'UK',
#       'zipCode': 'M14 5RD'},
#      'emergency': {'name': 'Michael Pendelton',
#       'relation': 'Brother',
#       'phone': '+44 7700 812334'}},
#     'complaint': 'Progressive abdominal swelling, yellowing of eyes and skin, ankle swelling, fatigue, and episodes of confusion over the past few weeks.',
#     'medical_history': ['Alcoholic liver cirrhosis',
#      'Esophageal varices (status post band ligation)',
#      'Major depressive disorder',
#      'Chronic alcohol use disorder'],
#     'allergies': []}},
#   {'message': 'Received. To build your timeline, please upload any past encounter reports or discharge summaries (e.g., from your Dentist, GP, or Urgent Care).',
#    'action_type': 'TEXT_ONLY',
#    'sender': 'admin'},
#   {'sender': 'patient',
#    'message': 'This is the previous encounter',
#    'attachments': ['patient_data_P0001_raw_data_encounter_report_0_2026-01-19.png_encounter_report_0_2026-01-19.png'],
#    'form_data': None},
#   {'message': 'Received. Do you have your blood test results (Labs)? Please upload all available reports, including older ones if you have them.',
#    'action_type': 'TEXT_ONLY',
#    'sender': 'admin'},
#   {'sender': 'patient',
#    'message': 'This is the lab report',
#    'attachments': ['patient_data_P0001_raw_data_lab_report_0_2025-07-19.png_lab_report_0_2025-07-19.png'],
#    'form_data': None},
#   {'message': 'Received. Do you have any radiology or imaging reports (Ultrasound, CT, MRI)?',
#    'action_type': 'TEXT_ONLY',
#    'sender': 'admin'},
#   {'sender': 'patient',
#    'message': 'I thiink the is the recent xray',
#    'attachments': ['patient_data_P0001_raw_data_imaging_report_0_2026-01-19.png_imaging_report_0_2026-01-19.png'],
#    'form_data': None},
#   {'message': 'Received. Finally, please upload the official Referral Letter from your referring doctor.',
#    'action_type': 'TEXT_ONLY',
#    'sender': 'admin'},
#   {'sender': 'patient',
#    'message': 'This one from my previous doctor',
#    'attachments': ['patient_data_P0001_referral_letter.png'],
#    'form_data': None},
#   {'message': 'Received. Thank you for providing all the documents. I have updated your file. Dr. Gupta has the following slots available:',
#    'action_type': 'OFFER_SLOTS',
#    'available_slots': {'doctorName': 'Dr. A. Gupta',
#     'specialty': 'Hepatology',
#     'slots': [{'slotId': 'SLOT_10_AM',
#       'date': '2025-12-10',
#       'time': '09:30 AM',
#       'type': 'In-Person'},
#      {'slotId': 'SLOT_11_PM',
#       'date': '2025-12-11',
#       'time': '02:00 PM',
#       'type': 'In-Person'},
#      {'slotId': 'SLOT_12_AM',
#       'date': '2025-12-12',
#       'time': '10:00 AM',
#       'type': 'In-Person'}]},
#    'sender': 'admin'},
#   {'sender': 'patient',
#    'message': 'I will take the slot on 2025-12-11 at 02:00 PM.',
#    'attachments': [],
#    'form_data': None},
#   {'message': 'Confirmed. Please arrive 15 minutes early.',
#    'action_type': 'CONFIRM_APPOINTMENT',
#    'confirmed_appointment': {'appointmentId': 'APPT789012',
#     'status': 'Confirmed',
#     'schedule': {'date': '2025-12-11',
#      'time': '02:00 PM',
#      'provider': 'Dr. A. Gupta',
#      'location': 'Hepatology Clinic',
#      'instructions': 'Please arrive 15 minutes prior to your appointment time.'}},
#    'sender': 'admin'}]}

# %%
files = gcs.list_files(folder_path="patient_data/P0001/")

# %%
import requests

url = "https://iso-clinic-v2.vercel.app/api/board-items"

response  = requests.get(url)
data = response.json()
with open("output/data_board.json", "w", encoding="utf-8") as f:
    json.dump(data, f, indent=4)

# %%
file_list = gcs.list_files("patient_data/P0001/board_items/")

board_objects = []

# results = []
for file in file_list:
    file_path = f"patient_data/P0001/board_items/{file}"
    raw_data = gcs.read_file_as_string(file_path)
    raw_objects = json.loads(raw_data)
    # results.append({
    #     "file" : file,
    #     "data": raw_objects
    # })

    if "referral.json" in file:
        rec = {
            "id": "referral-doctor-info",
            "date" : raw_objects.get("date",""),
            "visitType" : raw_objects.get("visitType",""),
            "provider" : raw_objects.get("provider",""),
            "specialty" : raw_objects.get("specialty",""),
            "rawText" : raw_objects.get("rawText",""),
            "dataSource" : raw_objects.get("dataSource",""),
            "highlights" : raw_objects.get("highlights",[]),
        }
        board_objects.append(rec)
        rec2 = {
            "id": "referral-letter-image",
            "date" : raw_objects.get("date",""),
            "studyType" : raw_objects.get("studyType",""),
            "provider" : raw_objects.get("provider",""),
            "specialty" : raw_objects.get("specialty",""),
            "imageUrl" : raw_objects.get("imageUrl",""),
            "dataSource" : raw_objects.get("dataSource",""),
        }
        board_objects.append(rec)
    elif "raw_images.json" in file:
        board_objects += raw_objects
    elif "encounters.json" in file:
        for i, e in enumerate(raw_objects):
            e['id'] = f"single-encounter-{i+1}"
            board_objects.append(e)
    elif "patient_context.json" in file:
        raw_objects['id'] = "dashboard-item-patient-context"
        board_objects.append(raw_objects)

        raw_objects['id'] = "sidebar-1"
        board_objects.append(raw_objects)
    elif "dashboard_analysis.json" in file:
        raw_objects['id'] = "adverse-event-analytics"
        board_objects.append(raw_objects)
    elif "dashboard_lab_latest.json" in file:
        board_objects.append({
            "id": "dashboard-item-lab-table",
            "labResults" : raw_objects
        })
    elif "dashboard_lab_chart.json" in file:
        board_objects.append({
            "id": "dashboard-item-lab-chart",
            "chartData" : raw_objects
        })
    elif "dashboard_pre_diagnosis.json" in file:
        board_objects.append({
            "id": "differential-diagnosis",
            "differential" : raw_objects
        })
    elif "dashboard_encounters_track.json" in file:
        board_objects.append({
            "id": "encounter-track-1",
            "encounters" : raw_objects
        })
    elif "dashboard_medication_track.json" in file:
        board_objects.append({
            "id": "medication-track-1",
            "data" : raw_objects
        })
    elif "dashboard_lab_track.json" in file:
        board_objects.append({
            "id": "lab-track-1",
            "data" : raw_objects
        })
    elif "dashboard_risk_event_track.json" in file:
        board_objects.append({
            "id": "risk-track-1",
            "risks" : raw_objects.get("risks")
        })
        board_objects.append({
            "id": "key-events-track-1",
            "events" : raw_objects.get("events")
        })

# %%
with open("board_preprocess_results.json", "w", encoding="utf-8") as f:
    json.dump(results, f,indent=4)

# %%
import requests

BASE_URL = "http://localhost:8000"

endpoint = f"{BASE_URL}/process/P0002/board-update"

response = requests.get(endpoint)
response.json()
# Out:
# {'status': 'success', 'message': 'Board objects have been processed.'}

# %%
import requests

BASE_URL = "http://localhost:8000"
# BASE_URL = "https://clinic-sim-pipeline-481780815788.europe-west1.run.app"

endpoint = f"{BASE_URL}/slots"

response = requests.get(endpoint)
# data = response.json()
# df = pd.DataFrame(data)
# df
response.status_code
# Out:
# 500

# %%
import requests

BASE_URL = "http://localhost:8000"
# BASE_URL = "https://clinic-sim-pipeline-481780815788.europe-west1.run.app"

endpoint = f"{BASE_URL}/schedule/switch"

payload = {
    "clinician_id": "N0001",
    "item1" : {
        "patient": "P0004",
        "date": "2026-01-22",
        "time": "11:00"
    },
    "item2" : {
        "patient": "P0005",
        "date": "2026-01-22",
        "time": "10:30"
    }

}

response = requests.post(endpoint, json=payload)
data = response.json()
data
# df = pd.DataFrame(data)
# df
# Out:
# {'message': 'Schedule updated successfully.'}

# %%
import requests

BASE_URL = "http://localhost:8000"
# BASE_URL = "https://clinic-sim-pipeline-481780815788.europe-west1.run.app"

endpoint = f"{BASE_URL}/data/P0001/board_objects.json"

response = requests.get(endpoint)
response.json()
# Out:
# [{'adverseEvents': [{'event': 'Hepatocellular Injury',
#     'severity': 'Severe',
#     'description': 'Elevated ALT (110.0 U/L) and AST (150.0 U/L) with a high ALT/AST ratio, indicative of hepatocellular damage.'},
#    {'event': 'Cholestatic Injury',
#     'severity': 'Severe',
#     'description': 'Elevated Total Bilirubin (6.8 mg/dL) with a high ALT/AST ratio, suggesting a cholestatic component.'},
#    {'event': 'Hepatic Encephalopathy',
#     'severity': 'Severe',
#     'description': "Patient presents with confusion, disorientation, and 'fuzzy brain', consistent with hepatic encephalopathy, exacerbated by alcohol relapse and poor medication compliance."},
#    {'event': 'Ascites',
#     'severity': 'Severe',
#     'description': 'Significant abdominal distension, positive fluid wave, and shifting dullness noted on examination, consistent with decompensated liver disease.'},
#    {'event': 'Hypoalbuminemia',
#     'severity': 'Moderate',
#     'description': 'Low serum albumin (2.2 g/dL) is consistent with chronic liver disease and impaired synthetic function.'},
#    {'event': 'Coagulopathy',
#     'severity': 'Severe',
#     'description': 'Elevated INR (2.1) indicates impaired synthesis of clotting factors by the liver.'},
#    {'event': 'Renal Impairment',
#     'severity': 'Mild',
#     'description': 'Elevated creatinine (1.3 mg/dL) may be indicative of hepatorenal syndrome or other renal insult.'},
#    {'event': 'Anemia',
#     'severity': 'Mild',
#     'description': 'Low Hemoglobin (10.2 g/dL) and low Platelets (125.0 x 10^3/uL) are common in chronic liver disease.'},
#    {'event': 'Hyponatremia',
#     'severity': 'Mild',
#     'description': 'Low serum sodium (132.0 mmol/L) can be seen in advanced liver disease and ascites.'}],
#   'rucam_ctcae_analysis': {'rucam': {'title': 'Roussel Uclaf Causality Assessment Method (RUCAM)',
#     'columns': ['Item', 'Score', 'Findings'],
#     'rows': [['1',
#       'Exclusion of alternative causes',
#       '+2',
#       'Viral hepatitis, autoimmune hepatitis, primary biliary cholangitis, drug-induced causes other than the suspected agent, and biliary obstruction are not explicitly ruled out but are unlikely given the established diagnosis of alcoholic liver cirrhosis and the temporal relationship with alcohol relapse.'],
#      ['2',
#       'Time to onset after starting or re-challenging with the suspected drug',
#       '+2',
#       'The patient has a known history of alcoholic liver cirrhosis. The current presentation of decompensation (ascites, encephalopathy, jaundice) is linked to a recent alcohol relapse (last two weeks) and poor medication compliance, rather than a new drug initiation. However, the exacerbation of liver injury is temporally related to the alcohol relapse.'],
#      ['3',
#       'Concomitant medications',
#       '0',
#       'Patient is on multiple medications (Lactulose, Furosemide, Propranolol, Sertraline, Thiamine, Folic Acid). While some of these can have rare hepatic side effects, the primary driver of decompensation appears to be alcohol. No other clear hepatotoxins were identified as new additions.'],
#      ['4',
#       "Patient's previous records of liver injury",
#       '+1',
#       'The patient has a known history of alcoholic liver cirrhosis, indicating pre-existing liver damage.'],
#      ['5',
#       'Response to withdrawal of the suspected drug',
#       '+1',
#       "The patient's symptoms are directly linked to alcohol relapse. Improvement is expected with alcohol abstinence and optimized medical management, but this is not a direct response to withdrawing a specific hepatotoxic drug."],
#      ['6',
#       'Age > 55 years',
#       '+1',
#       'Patient is 54 years old, not meeting this criterion.'],
#      ['7',
#       'Alcohol consumption',
#       '+1',
#       'Patient admits to a recent relapse in alcohol consumption (8-10 units/day for the last two weeks), which is a known risk factor for decompensation in alcoholic liver cirrhosis.'],
#      ['8',
#       'Other risk factors',
#       '0',
#       'No other specific risk factors for DILI are mentioned.']],
#     'total_score': 8,
#     'causality_category': 'Probable'},
#    'ctcae': {'title': 'Common Terminology Criteria for Adverse Events (CTCAE) v5.0 - Liver',
#     'columns': ['Lab Parameter', 'Result', 'Reference Range', 'CTCAE Grade'],
#     'rows': [['ALT', '110.0 U/L', '7.0 - 56.0 U/L', 'Grade 2'],
#      ['AST', '150.0 U/L', '10.0 - 40.0 U/L', 'Grade 2'],
#      ['Total Bilirubin', '6.8 mg/dL', '0.2 - 1.2 mg/dL', 'Grade 3'],
#      ['INR', '2.1', '0.9 - 1.1', 'Grade 3'],
#      ['Albumin', '2.2 g/dL', '3.4 - 5.4 g/dL', 'Grade 2'],
#      ['Creatinine', '1.3 mg/dL', '0.6 - 1.2 mg/dL', 'Grade 1']],
#     'overall_grade': 'Grade 3'},
#    'reasoning': "The patient, Arthur Pendelton, a 54-year-old male with a known history of alcoholic liver cirrhosis (Child-Pugh B), presents with acute decompensation characterized by ascites, hepatic encephalopathy, jaundice, and coagulopathy. The RUCAM assessment yields a score of 8, categorizing the event as 'Probable'. While the patient has a known liver condition, the recent alcohol relapse (8-10 units/day for two weeks) and poor medication compliance are the primary triggers for this decompensation. The RUCAM score is influenced by the exclusion of other causes (though not definitively ruled out), the temporal relationship to the alcohol relapse, pre-existing liver injury, and the patient's alcohol consumption. The CTCAE grading highlights severe liver dysfunction, with Grade 3 elevations in Total Bilirubin and INR, and Grade 2 elevations in ALT and AST. The overall clinical picture strongly suggests decompensation of known alcoholic liver cirrhosis, exacerbated by alcohol relapse and non-adherence to treatment, rather than a new drug-induced liver injury from his current medications. The elevated liver enzymes and bilirubin, coupled with clinical signs of encephalopathy and ascites, are consistent with the progression of his underlying liver disease."},
#   'id': 'adverse-event-analytics',
#   'componentType': 'AdverseEventAnalytics',
#   'zone': 'adv-event-zone'},
#  {'id': 'encounter-track-1',
#   'componentType': 'EncounterTrack',
#   'zone': 'adv-event-zone',
#   'encounters': [{'encounter_no': 1,
#     'date': '2025-07-19',
#     'type': 'Emergency Department Visit',
#     'provider': 'Dr. Eleanor Vance',
#     'chief_complaint': 'Progressive abdominal distension, jaundice, confusion, and ankle swelling.',
#     'medications': ['Lactulose (Started)',
#      'Furosemide (Started)',
#      'Normal Saline (Started)',
#      'Thiamine (Started)',
#      'Folic Acid (Started)'],
#     'impression': 'Decompensated Alcoholic Liver Cirrhosis with Ascites and Hepatic Encephalopathy',
#     'differential_diagnosis': ['Acute Liver Failure',
#      'Sepsis',
#      'Gastrointestinal Bleed'],
#     'notes': 'Patient admitted to the General Medical ward for management of decompensated alcoholic liver cirrhosis, ascites, and hepatic encephalopathy. Strict fluid balance monitoring, low sodium diet, and alcohol abstinence enforced. Regular neurological checks initiated.',
#     'casual_reason': "This emergency department visit marks the initial diagnosis and acute management of decompensated alcoholic liver cirrhosis, ascites, and hepatic encephalopathy, directly stemming from the patient's recent alcohol relapse and likely poor medication compliance. The initiation of Lactulose, Furosemide, Thiamine, and Folic Acid began the treatment for these critical conditions."},
#    {'encounter_no': 2,
#     'date': '2025-10-19',
#     'type': 'Follow-up Visit',
#     'provider': 'Dr. Eleanor Vance',
#     'chief_complaint': 'Follow-up after hospital admission for decompensated alcoholic liver cirrhosis.',
#     'medications': ['Lactulose (Continued)',
#      'Furosemide (Continued)',
#      'Propranolol (Continued)',
#      'Sertraline (Started)',
#      'Thiamine (Continued)',
#      'Folic Acid (Continued)'],
#     'impression': 'Stable Alcoholic Liver Cirrhosis, improved from decompensation. Continued risk of decompensation with continued alcohol use.',
#     'differential_diagnosis': [],
#     'notes': 'Patient reports improved symptoms since hospital admission. Alcohol intake reduced, and Furosemide compliance noted. Prescribed new medications for depression and continued existing ones. Regular follow-up scheduled.',
#     'casual_reason': 'This follow-up visit indicates a period of improvement and stabilization following the acute decompensation. The initiation of Sertraline suggests management of co-existing depression, which can be a factor in chronic illness management. The continued use of Lactulose, Furosemide, and Propranolol reflects ongoing management of ascites and portal hypertension, with an emphasis on medication compliance and alcohol abstinence.'},
#    {'encounter_no': 3,
#     'date': '2026-01-19',
#     'type': 'Urgent Care Visit',
#     'provider': 'Dr. Anya Sharma',
#     'chief_complaint': 'Return of ascites, confusion, and poor medication compliance with recent alcohol relapse.',
#     'medications': ['Lactulose (Continued)',
#      'Furosemide (Continued)',
#      'Propranolol (Continued)'],
#     'impression': 'Decompensated Alcoholic Liver Cirrhosis with Ascites and Hepatic Encephalopathy',
#     'differential_diagnosis': ['Decompensated Liver Disease',
#      'Ascites of unknown origin',
#      'Hepatic Encephalopathy'],
#     'notes': 'Patient presented with significant worsening of symptoms, including ascites and confusion, attributed to poor medication compliance and alcohol relapse. Urgent hospital referral advised.',
#     'casual_reason': "This visit highlights a significant relapse and decompensation, directly linked to the patient's poor medication compliance (Lactulose, Furosemide, Propranolol) and a recent alcohol relapse. The return of ascites and confusion indicates a failure in the previous management plan, necessitating urgent hospital referral and re-evaluation of treatment strategies."}]},
#  {'id': 'dashboard-item-lab-chart',
#   'componentType': 'LabChart',
#   'zone': 'adv-event-zone',
#   'chartData': [{'biomarker': 'ALT',
#     'data': [{'date': '2025-10-19', 'value': 110.0, 'unit': 'U/L'},
#      {'date': '2026-01-19', 'value': 110.0, 'unit': 'U/L'}]},
#    {'biomarker': 'AST',
#     'data': [{'date': '2025-10-19', 'value': 150.0, 'unit': 'U/L'},
#      {'date': '2026-01-19', 'value': 150.0, 'unit': 'U/L'}]},
#    {'biomarker': 'Total Bilirubin',
#     'data': [{'date': '2025-10-19', 'value': 6.8, 'unit': 'mg/dL'},
#      {'date': '2026-01-19', 'value': 6.8, 'unit': 'mg/dL'}]},
#    {'biomarker': 'Albumin',
#     'data': [{'date': '2025-10-19', 'value': 2.2, 'unit': 'g/dL'},
#      {'date': '2026-01-19', 'value': 2.2, 'unit': 'g/dL'}]},
#    {'biomarker': 'Prothrombin Time (PT) / INR',
#     'data': [{'date': '2025-10-19', 'value': 2.1, 'unit': 'INR'},
#      {'date': '2026-01-19', 'value': 2.1, 'unit': 'INR'}]},
#    {'biomarker': 'Sodium',
#     'data': [{'date': '2025-10-19', 'value': 132.0, 'unit': 'mmol/L'},
#      {'date': '2026-01-19', 'value': 132.0, 'unit': 'mmol/L'}]},
#    {'biomarker': 'Potassium',
#     'data': [{'date': '2025-10-19', 'value': 4.5, 'unit': 'mmol/L'},
#      {'date': '2026-01-19', 'value': 4.5, 'unit': 'mmol/L'}]},
#    {'biomarker': 'Creatinine',
#     'data': [{'date': '2025-10-19', 'value': 1.3, 'unit': 'mg/dL'},
#      {'date': '2026-01-19', 'value': 1.3, 'unit': 'mg/dL'}]},
#    {'biomarker': 'White Blood Cell Count',
#     'data': [{'date': '2025-10-19', 'value': 9.8, 'unit': '10^3/uL'},
#      {'date': '2026-01-19', 'value': 9.8, 'unit': '10^3/uL'}]},
#    {'biomarker': 'Hemoglobin',
#     'data': [{'date': '2025-10-19', 'value': 10.2, 'unit': 'g/dL'},
#      {'date': '2026-01-19', 'value': 10.2, 'unit': 'g/dL'}]},
#    {'biomarker': 'Platelets',
#     'data': [{'date': '2025-10-19', 'value': 125.0, 'unit': '10^3/uL'},
#      {'date': '2026-01-19', 'value': 125.0, 'unit': '10^3/uL'}]}]},
#  {'id': 'dashboard-item-lab-table',
#   'componentType': 'LabTable',
#   'zone': 'adv-event-zone',
#   'labResults': [{'name': 'WBC',
#     'value': 9.8,
#     'unit': '10^3/uL',
#     'normalRange': '3.4 - 10.8',
#     'status': 'normal',
#     'previousValue': None,
#     'date': '2026-01-19'},
#    {'name': 'Hemoglobin',
#     'value': 10.2,
#     'unit': 'g/dL',
#     'normalRange': '13.5 - 17.5',
#     'status': 'low',
#     'previousValue': None,
#     'date': '2026-01-19'},
#    {'name': 'Platelets',
#     'value': 125.0,
#     'unit': '10^3/uL',
#     'normalRange': '150.0 - 450.0',
#     'status': 'low',
#     'previousValue': None,
#     'date': '2026-01-19'},
#    {'name': 'AST',
#     'value': 150.0,
#     'unit': 'U/L',
#     'normalRange': '10.0 - 40.0',
#     'status': 'high',
#     'previousValue': None,
#     'date': '2026-01-19'},
#    {'name': 'ALT',
#     'value': 110.0,
#     'unit': 'U/L',
#     'normalRange': '7.0 - 56.0',
#     'status': 'high',
#     'previousValue': None,
#     'date': '2026-01-19'},
#    {'name': 'Total Bilirubin',
#     'value': 6.8,
#     'unit': 'mg/dL',
#     'normalRange': '0.2 - 1.2',
#     'status': 'high',
#     'previousValue': None,
#     'date': '2026-01-19'},
#    {'name': 'Albumin',
#     'value': 2.2,
#     'unit': 'g/dL',
#     'normalRange': '3.4 - 5.4',
#     'status': 'low',
#     'previousValue': None,
#     'date': '2026-01-19'},
#    {'name': 'Prothrombin Time (PT) / INR',
#     'value': 2.1,
#     'unit': 'INR',
#     'normalRange': '0.9 - 1.1',
#     'status': 'high',
#     'previousValue': None,
#     'date': '2026-01-19'},
#    {'name': 'Sodium',
#     'value': 132.0,
#     'unit': 'mmol/L',
#     'normalRange': '135.0 - 145.0',
#     'status': 'low',
#     'previousValue': None,
#     'date': '2026-01-19'},
#    {'name': 'Potassium',
#     'value': 4.5,
#     'unit': 'mmol/L',
#     'normalRange': '3.5 - 5.0',
#     'status': 'normal',
#     'previousValue': None,
#     'date': '2026-01-19'},
#    {'name': 'Creatinine',
#     'value': 1.3,
#     'unit': 'mg/dL',
#     'normalRange': '0.6 - 1.2',
#     'status': 'high',
#     'previousValue': None,
#     'date': '2026-01-19'}]},
#  {'id': 'lab-track-1',
#   'componentType': 'LabTrack',
#   'zone': 'adv-event-zone',
#   'data': [{'biomarker': 'WBC',
#     'unit': '10^3/uL',
#     'referenceRange': {'min': 3.4, 'max': 10.8},
#     'values': [{'t': '2026-01-19T00:00:00', 'value': 9.8}]},
#    {'biomarker': 'Hemoglobin',
#     'unit': 'g/dL',
#     'referenceRange': {'min': 13.5, 'max': 17.5},
#     'values': [{'t': '2026-01-19T00:00:00', 'value': 10.2}]},
#    {'biomarker': 'Platelets',
#     'unit': '10^3/uL',
#     'referenceRange': {'min': 150.0, 'max': 450.0},
#     'values': [{'t': '2026-01-19T00:00:00', 'value': 125.0}]},
#    {'biomarker': 'AST',
#     'unit': 'U/L',
#     'referenceRange': {'min': 10.0, 'max': 40.0},
#     'values': [{'t': '2026-01-19T00:00:00', 'value': 150.0}]},
#    {'biomarker': 'ALT',
#     'unit': 'U/L',
#     'referenceRange': {'min': 7.0, 'max': 56.0},
#     'values': [{'t': '2026-01-19T00:00:00', 'value': 110.0}]},
#    {'biomarker': 'Total Bilirubin',
#     'unit': 'mg/dL',
#     'referenceRange': {'min': 0.2, 'max': 1.2},
#     'values': [{'t': '2026-01-19T00:00:00', 'value': 6.8}]},
#    {'biomarker': 'Albumin',
#     'unit': 'g/dL',
#     'referenceRange': {'min': 3.4, 'max': 5.4},
#     'values': [{'t': '2026-01-19T00:00:00', 'value': 2.2}]},
#    {'biomarker': 'Prothrombin Time (PT) / INR',
#     'unit': 'INR',
#     'referenceRange': {'min': 0.9, 'max': 1.1},
#     'values': [{'t': '2026-01-19T00:00:00', 'value': 2.1}]},
#    {'biomarker': 'Sodium',
#     'unit': 'mmol/L',
#     'referenceRange': {'min': 135.0, 'max': 145.0},
#     'values': [{'t': '2026-01-19T00:00:00', 'value': 132.0}]},
#    {'biomarker': 'Potassium',
#     'unit': 'mmol/L',
#     'referenceRange': {'min': 3.5, 'max': 5.0},
#     'values': [{'t': '2026-01-19T00:00:00', 'value': 4.5}]},
#    {'biomarker': 'Creatinine',
#     'unit': 'mg/dL',
#     'referenceRange': {'min': 0.6, 'max': 1.2},
#     'values': [{'t': '2026-01-19T00:00:00', 'value': 1.3}]}]},
#  {'id': 'medication-track-1',
#   'componentType': 'MedicationTrack',
#   'zone': 'adv-event-zone',
#   'data': {'encounters': [{'encounter_no': 1, 'date': '2026-01-19'},
#     {'encounter_no': 2, 'date': '2025-10-19'},
#     {'encounter_no': 3, 'date': '2025-07-19'}],
#    'medications': [{'name': 'Lactulose',
#      'startDate': '2025-07-19',
#      'endDate': '2026-01-19',
#      'dose': '30ml',
#      'indication': 'Hepatic encephalopathy'},
#     {'name': 'Furosemide',
#      'startDate': '2025-07-19',
#      'endDate': '2026-01-19',
#      'dose': '20mg',
#      'indication': 'Ascites'},
#     {'name': 'Normal Saline',
#      'startDate': '2025-07-19',
#      'endDate': '2025-07-19',
#      'dose': '75 ml/hr',
#      'indication': 'Fluid resuscitation'},
#     {'name': 'Thiamine',
#      'startDate': '2025-07-19',
#      'endDate': '2026-01-19',
#      'dose': '100mg',
#      'indication': 'Alcoholic liver disease'},
#     {'name': 'Folic Acid',
#      'startDate': '2025-07-19',
#      'endDate': '2026-01-19',
#      'dose': '5mg',
#      'indication': 'Alcoholic liver disease'},
#     {'name': 'Propranolol',
#      'startDate': '2025-10-19',
#      'endDate': '2026-01-19',
#      'dose': '40mg',
#      'indication': 'Portal hypertension/varices prophylaxis'},
#     {'name': 'Sertraline',
#      'startDate': '2025-10-19',
#      'endDate': '2026-01-19',
#      'dose': '50mg',
#      'indication': 'Depression'}]}},
#  {'id': 'differential-diagnosis',
#   'componentType': 'DifferentialDiagnosis',
#   'zone': 'adv-event-zone',
#   'differential': [{'diagnosis': 'Decompensated Alcoholic Liver Cirrhosis',
#     'status': 'high',
#     'note': 'Patient has a known history of alcoholic liver cirrhosis, with recent decompensation evidenced by ascites, confusion, jaundice, and abnormal LFTs (AST 150, ALT 110, Bilirubin 6.8, Albumin 2.2, INR 2.1). Ultrasound confirms liver changes consistent with chronic cirrhosis and significant ascites. Recent alcohol relapse is a clear precipitating factor.'},
#    {'diagnosis': 'Hepatic Encephalopathy',
#     'status': 'high',
#     'note': "Patient presents with confusion and disorientation, described as 'brain's gone all fuzzy'. This is a known complication of decompensated liver disease, supported by the elevated bilirubin and INR, and history of cirrhosis."},
#    {'diagnosis': 'Ascites',
#     'status': 'high',
#     'note': 'Physical exam findings of abdominal distension, positive fluid wave, and shifting dullness, along with imaging (ultrasound and CXR) confirming significant fluid in the peritoneal cavity, are classic signs of ascites, a common complication of decompensated liver cirrhosis.'},
#    {'diagnosis': 'Alcoholic Hepatitis',
#     'status': 'medium',
#     'note': 'While the primary diagnosis is decompensated cirrhosis, the recent alcohol relapse and elevated AST/ALT (150/110) could indicate superimposed alcoholic hepatitis. However, the chronicity of symptoms and ultrasound findings point more strongly to cirrhosis as the primary driver.'},
#    {'diagnosis': 'Spontaneous Bacterial Peritonitis (SBP)',
#     'status': 'low',
#     'note': 'While ascites is present, there are no specific symptoms mentioned (e.g., fever, worsening abdominal pain, or signs of sepsis) to strongly suggest SBP. However, it remains a potential complication in patients with decompensated cirrhosis and ascites.'},
#    {'diagnosis': 'Acute Kidney Injury (AKI)',
#     'status': 'medium',
#     'note': 'The patient has a creatinine of 1.3 mg/dL, which is elevated from the normal range and concerning in the context of decompensated liver disease and potential diuretic use. This could represent hepatorenal syndrome or another cause of AKI.'}]},
#  {'id': 'risk-track-1',
#   'componentType': 'RiskTrack',
#   'zone': 'adv-event-zone',
#   'risks': [{'t': '2023-10-26T00:00:00Z',
#     'riskScore': 7,
#     'factors': ['Abdominal distension',
#      'Altered mental status',
#      'History of alcohol abuse',
#      'Decompensated liver disease',
#      'Significant ascites',
#      'Splenomegaly']},
#    {'t': '2025-07-19T02:15:00Z',
#     'riskScore': 9,
#     'factors': ['Progressive abdominal distension',
#      'Jaundice',
#      'Confusion',
#      'Ankle swelling',
#      'Alcohol relapse',
#      'Decompensated Alcoholic Liver Cirrhosis',
#      'Hepatic Encephalopathy',
#      'Ascites',
#      'Asterixis',
#      'ED Visit']},
#    {'t': '2025-10-19T10:00:00Z',
#     'riskScore': 5,
#     'factors': ['Improved symptoms post-hospitalization',
#      'Inconsistent Lactulose use',
#      'Reduced alcohol intake (2-3 units/day)',
#      'Fatigue',
#      'Poor appetite',
#      'Stable Alcoholic Liver Cirrhosis']},
#    {'t': '2026-01-19T09:00:00Z',
#     'riskScore': 10,
#     'factors': ['Return of ascites',
#      'Confusion',
#      'Poor medication compliance',
#      'Recent alcohol relapse (8-10 units/day)',
#      'Nausea',
#      'Poor appetite',
#      'Jaundice',
#      'Disorientation',
#      'Markedly distended abdomen',
#      'Positive fluid wave',
#      'Shifting dullness',
#      'Bilateral pitting edema up to mid-shin',
#      'Low Hemoglobin',
#      'Low Platelets',
#      'High AST',
#      'High ALT',
#      'High Total Bilirubin',
#      'Low Albumin',
#      'High INR',
#      'Low Sodium',
#      'High Creatinine']}]},
#  {'id': 'key-events-track-1',
#   'componentType': 'KeyEventsTrack',
#   'zone': 'adv-event-zone',
#   'events': [{'event': 'Imaging: Abdominal Ultrasound',
#     't': '2023-10-26T00:00:00Z',
#     'note': 'Findings suggestive of decompensated alcoholic liver cirrhosis with significant ascites and splenomegaly.'},
#    {'event': 'Imaging: Chest X-ray',
#     't': '2025-07-19T00:00:00Z',
#     'note': 'Findings suggestive of significant ascites.'},
#    {'event': 'Emergency Department Visit',
#     't': '2025-07-19T02:15:00Z',
#     'note': 'Patient presented with progressive abdominal distension, jaundice, confusion, and ankle swelling, indicating decompensated alcoholic liver cirrhosis. Admission to hospital and initiation of IV Furosemide and Lactulose.'},
#    {'event': 'Medication Change: Furosemide IV',
#     't': '2025-07-19T02:15:00Z',
#     'note': 'Furosemide initiated at 40mg IV due to severe ascites.'},
#    {'event': 'Medication Change: Lactulose IV/Oral',
#     't': '2025-07-19T02:15:00Z',
#     'note': 'Lactulose initiated at 30ml Oral every 2-3 hours for hepatic encephalopathy.'},
#    {'event': 'Follow-up Visit',
#     't': '2025-10-19T10:00:00Z',
#     'note': 'Patient reports improvement in symptoms post-hospitalization. New medication regimen established including Lactulose, Furosemide, Propranolol, Sertraline, Thiamine, and Folic Acid.'},
#    {'event': 'Medication Start: Sertraline',
#     't': '2025-10-19T10:00:00Z',
#     'note': 'Sertraline 50mg daily started for depression.'},
#    {'event': 'Medication Start: Thiamine',
#     't': '2025-10-19T10:00:00Z',
#     'note': 'Thiamine 100mg daily started for alcoholic liver disease.'},
#    {'event': 'Medication Start: Folic Acid',
#     't': '2025-10-19T10:00:00Z',
#     'note': 'Folic Acid 5mg daily started for alcoholic liver disease.'},
#    {'event': 'Urgent Care Visit',
#     't': '2026-01-19T09:00:00Z',
#     'note': 'Patient presents with significant decompensation: return of ascites, confusion, jaundice, and poor medication compliance with alcohol relapse. Critical lab values noted.'},
#    {'event': 'Lab Result: High ALT',
#     't': '2026-01-19T00:00:00Z',
#     'note': 'ALT elevated to 110.0 U/L, indicating significant liver injury.'},
#    {'event': 'Lab Result: High Total Bilirubin',
#     't': '2026-01-19T00:00:00Z',
#     'note': 'Total Bilirubin elevated to 6.8 mg/dL, contributing to jaundice.'},
#    {'event': 'Lab Result: Low Albumin',
#     't': '2026-01-19T00:00:00Z',
#     'note': 'Albumin low at 2.2 g/dL, indicating impaired synthetic function of the liver.'},
#    {'event': 'Lab Result: High INR',
#     't': '2026-01-19T00:00:00Z',
#     'note': 'INR elevated to 2.1, indicating coagulopathy.'},
#    {'event': 'Lab Result: High Creatinine',
#     't': '2026-01-19T00:00:00Z',
#     'note': 'Creatinine elevated to 1.3 mg/dL, suggesting potential renal impairment.'},
#    {'event': 'Referral: Hepatology Registrar',
#     't': '2026-01-20T00:00:00Z',
#     'note': 'Urgent referral to Hepatology Registrar due to acute decompensation, ascites, and hepatic encephalopathy, likely secondary to poor medication compliance and alcohol relapse.'}]},
#  {'encounter': {'encounter_no': 1,
#    'meta': {'visit_type': 'Urgent Care Visit',
#     'date_time': '2026-01-19T09:00:00Z',
#     'provider': {'name': 'Dr. Anya Sharma',
#      'specialty': 'General Practitioner'},
#     'ui_risk_color': 'red'},
#    'assessment': {'impression': 'Decompensated Alcoholic Liver Cirrhosis with Ascites and Hepatic Encephalopathy',
#     'differential': ['Decompensated Liver Disease',
#      'Ascites of unknown origin',
#      'Hepatic Encephalopathy']},
#    'chief_complaint': 'Return of ascites, confusion, and poor medication compliance with recent alcohol relapse.',
#    'hpi': 'Patient presents to his GP feeling significantly unwell, reporting a return of his abdominal distension over the past week, stating his trousers are "too tight again." He also notes increased episodes of confusion and forgetfulness, describing it as "my brain\'s gone all fuzzy." He admits to relapsing into heavier alcohol consumption over the last two weeks, averaging around 8-10 units per day, and finding it difficult to stop. He reports feeling nauseous and has had a poor appetite. He hasn\'t been taking his Lactulose regularly because "it makes me run to the loo too much." He has also missed several doses of his Furosemide and Propranolol. He denies any chest pain, shortness of breath, or fever.',
#    'medications_prior': [{'name': 'Lactulose',
#      'route': 'Oral',
#      'indication': 'Ascites/Hepatic Encephalopathy'},
#     {'name': 'Furosemide', 'route': 'Oral', 'indication': 'Ascites'},
#     {'name': 'Propranolol',
#      'route': 'Oral',
#      'indication': 'Portal Hypertension/Varices Prophylaxis'}],
#    'physical_exam': {'general': 'Unwell, distended abdomen, yellow tinge to skin, slightly disoriented, speaks slowly.',
#     'head_neck': '',
#     'other_systems': 'Abdomen: Markedly distended, tense, positive fluid wave and shifting dullness. Mild diffuse tenderness. Lungs: Clear, diminished breath sounds at bases. Cardiovascular: Tachycardic, regular rhythm. Extremities: Bilateral pitting edema up to mid-shin.'},
#    'plan': {'investigations': {'labs': [], 'imaging': []},
#     'management': {'follow_up': 'Urgent hospital referral.',
#      'instructions': 'Continue current management.',
#      'medications_started': [{'name': 'Lactulose',
#        'dose': '500 grg',
#        'route': 'Oral',
#        'frequency': 'as directed',
#        'indication': 'Ascites'},
#       {'name': 'Furosemide',
#        'dose': '200 grg',
#        'route': 'Oral',
#        'frequency': 'as directed',
#        'indication': 'Ascites'},
#       {'name': 'Propranolol',
#        'dose': '100 grg',
#        'route': 'Oral',
#        'frequency': 'as directed',
#        'indication': 'Portal Hypertension'}]}},
#    'reason_for_visit': 'Return of ascites, confusion, and poor medication compliance with recent alcohol relapse.'},
#   'patient': {'name': 'Arthur Pendelton',
#    'sex': 'Male',
#    'age_at_first_encounter': 54},
#   'encounterIndex': 0,
#   'dataSource': 'SPRINGFIELD FAMILY CLINIC - URGENT CARE',
#   'id': 'single-encounter-1',
#   'componentType': 'SingleEncounterDocument',
#   'zone': 'data-zone'},
#  {'encounter': {'encounter_no': 2,
#    'meta': {'visit_type': 'Follow-up Visit',
#     'date_time': '2025-10-19T10:00:00Z',
#     'provider': {'name': 'Dr. Eleanor Vance',
#      'specialty': 'Gastroenterologist'},
#     'ui_risk_color': 'green'},
#    'assessment': {'impression': 'Stable Alcoholic Liver Cirrhosis, improved from decompensation. Continued risk of decompensation with continued alcohol use.',
#     'differential': []},
#    'chief_complaint': 'Follow-up after hospital admission for decompensated alcoholic liver cirrhosis.',
#    'hpi': 'Patient presents for scheduled follow-up. He reports improved abdominal distension and reduced confusion since his recent admission for decompensated alcoholic liver cirrhosis. He states he has been taking Lactulose inconsistently and has reduced alcohol intake to 2-3 units per day, with occasional slip-ups. He still experiences fatigue and poor appetite but feels generally better. He has been compliant with Furosemide and has noticed reduced ankle swelling.',
#    'medications_prior': [{'name': 'Lactulose',
#      'route': 'Oral',
#      'indication': 'Hepatic encephalopathy'},
#     {'name': 'Furosemide', 'route': 'Oral', 'indication': 'Ascites'},
#     {'name': 'Propranolol',
#      'route': 'Oral',
#      'indication': 'Portal hypertension/varices prophylaxis'},
#     {'name': 'Sertraline', 'route': 'Oral', 'indication': 'Depression'},
#     {'name': 'Thiamine',
#      'route': 'Oral',
#      'indication': 'Alcoholic liver disease'},
#     {'name': 'Folic Acid',
#      'route': 'Oral',
#      'indication': 'Alcoholic liver disease'}],
#    'physical_exam': {'general': 'Improved alertness, less jaundice.',
#     'head_neck': '',
#     'other_systems': 'Abdomen: Mildly distended. Trace pitting edema at the ankles.'},
#    'plan': {'investigations': {'labs': ['Liver Function Tests (LFTs)',
#       'CBC',
#       'Electrolytes',
#       'Renal Function'],
#      'imaging': []},
#     'management': {'follow_up': 'Regular clinic appointments every 4 weeks.',
#      'instructions': 'Continue strict alcohol abstinence. Aim for a low-sodium diet. Emphasized importance of regular medication compliance.',
#      'medications_started': [{'name': 'Lactulose',
#        'dose': '30ml',
#        'route': 'Oral',
#        'frequency': 'three times daily',
#        'indication': 'Hepatic encephalopathy'},
#       {'name': 'Furosemide',
#        'dose': '20mg',
#        'route': 'Oral',
#        'frequency': 'twice daily',
#        'indication': 'Ascites'},
#       {'name': 'Propranolol',
#        'dose': '40mg',
#        'route': 'Oral',
#        'frequency': 'twice daily',
#        'indication': 'Portal hypertension/varices prophylaxis'},
#       {'name': 'Sertraline',
#        'dose': '50mg',
#        'route': 'Oral',
#        'frequency': 'daily',
#        'indication': 'Depression'},
#       {'name': 'Thiamine',
#        'dose': '100mg',
#        'route': 'Oral',
#        'frequency': 'daily',
#        'indication': 'Alcoholic liver disease'},
#       {'name': 'Folic Acid',
#        'dose': '5mg',
#        'route': 'Oral',
#        'frequency': 'daily',
#        'indication': 'Alcoholic liver disease'}]}},
#    'reason_for_visit': 'Follow-up after hospital admission for decompensated alcoholic liver cirrhosis.'},
#   'patient': {'name': 'Arthur Pendelton',
#    'sex': 'Male',
#    'age_at_first_encounter': 54},
#   'encounterIndex': 1,
#   'dataSource': 'SPRINGFIELD GASTROENTEROLOGY CLINIC',
#   'id': 'single-encounter-2',
#   'componentType': 'SingleEncounterDocument',
#   'zone': 'data-zone'},
#  {'encounter': {'encounter_no': 3,
#    'meta': {'visit_type': 'Emergency Department Visit',
#     'date_time': '2025-07-19T02:15:00Z',
#     'provider': {'name': 'Dr. Eleanor Vance',
#      'specialty': 'Gastroenterologist'},
#     'ui_risk_color': 'red'},
#    'assessment': {'impression': 'Decompensated Alcoholic Liver Cirrhosis with Ascites and Hepatic Encephalopathy',
#     'differential': ['Acute Liver Failure',
#      'Sepsis',
#      'Gastrointestinal Bleed']},
#    'chief_complaint': 'Progressive abdominal distension, jaundice, confusion, and ankle swelling.',
#    'hpi': 'Patient presents with a 2-3 week history of progressive abdominal distension, jaundice noted for one week, and increasing confusion, forgetfulness, and difficulty concentrating over the last few days. He also reports significant bilateral ankle swelling, fatigue, and nausea. Patient admits to recent relapse in alcohol consumption.',
#    'medications_prior': [],
#    'physical_exam': {'general': 'Jaundiced, disoriented with asterixis.',
#     'head_neck': '',
#     'other_systems': 'Marked abdominal distension with ascites. Bilateral pitting edema.'},
#    'plan': {'investigations': {'labs': ['CBC',
#       'CMP',
#       'Coags',
#       'Blood cultures',
#       'UA'],
#      'imaging': ['Abdominal Ultrasound', 'Chest X-ray']},
#     'management': {'follow_up': 'Admission to the General Medical ward.',
#      'instructions': 'Strict fluid balance monitoring and low sodium diet. Strict alcohol abstinence to be enforced. Regular neurological checks.',
#      'medications_started': [{'name': 'Lactulose',
#        'dose': '30ml',
#        'route': 'Oral',
#        'frequency': 'every 2-3 hours until bowel movements established, then titrate',
#        'indication': 'Hepatic encephalopathy'},
#       {'name': 'Furosemide',
#        'dose': '40mg',
#        'route': 'IV',
#        'frequency': 'once, then 20mg orally twice daily',
#        'indication': 'Ascites'},
#       {'name': 'Normal Saline',
#        'dose': '75 ml/hr',
#        'route': 'IV',
#        'frequency': 'continuous',
#        'indication': 'Fluid resuscitation'},
#       {'name': 'Thiamine',
#        'dose': '100mg',
#        'route': 'IV',
#        'frequency': 'once, then 100mg orally daily',
#        'indication': 'Alcoholic liver disease'},
#       {'name': 'Folic Acid',
#        'dose': '5mg',
#        'route': 'Oral',
#        'frequency': 'daily',
#        'indication': 'Alcoholic liver disease'}]}},
#    'reason_for_visit': 'Progressive abdominal distension, jaundice, confusion, and ankle swelling.'},
#   'patient': {'name': 'Arthur Pendelton',
#    'sex': 'Male',
#    'age_at_first_encounter': 54},
#   'encounterIndex': 2,
#   'dataSource': 'CITY GENERAL HOSPITAL - EMERGENCY DEPT',
#   'id': 'single-encounter-3',
#   'componentType': 'SingleEncounterDocument',
#   'zone': 'data-zone'},
#  {'description': 'Arthur Pendelton is a 54-year-old male presenting with decompensated alcoholic liver cirrhosis, experiencing worsening ascites, confusion, jaundice, and poor medication compliance with a recent alcohol relapse.',
#   'patient': {'name': 'Arthur Pendelton',
#    'date_of_birth': '1970-03-15',
#    'age': 55,
#    'sex': 'Male',
#    'identifiers': {'mrn': 'P0001'}},
#   'riskLevel': 'critical',
#   'primaryDiagnosis': 'Decompensated Alcoholic Liver Cirrhosis with Ascites and Hepatic Encephalopathy',
#   'problem_list': [{'name': 'Decompensated Alcoholic Liver Cirrhosis',
#     'status': 'active'},
#    {'name': 'Ascites', 'status': 'active'},
#    {'name': 'Hepatic Encephalopathy', 'status': 'active'},
#    {'name': 'Jaundice', 'status': 'active'},
#    {'name': 'Confusion', 'status': 'active'},
#    {'name': 'Alcohol Relapse', 'status': 'active'},
#    {'name': 'Poor Medication Compliance', 'status': 'active'},
#    {'name': 'Esophageal Varices', 'status': 'chronic'},
#    {'name': 'Depression', 'status': 'chronic'},
#    {'name': 'Ankle Swelling', 'status': 'active'},
#    {'name': 'Nausea', 'status': 'active'},
#    {'name': 'Poor Appetite', 'status': 'active'}],
#   'medication_timeline': [{'name': 'Lactulose',
#     'dose': '500 grg',
#     'route': 'Oral',
#     'frequency': 'to one other afculpating ascite (etre consly)',
#     'start': '2026-01-19',
#     'end': 'Ongoing'},
#    {'name': 'Furosemide',
#     'dose': '200 grg',
#     'route': 'Oral',
#     'frequency': 'as-nzety 400 mg/for 1tiz.m in morteh',
#     'start': '2026-01-19',
#     'end': 'Ongoing'},
#    {'name': 'Propranolol',
#     'dose': '100 grg',
#     'route': 'Oral',
#     'frequency': 'da-apsity 300 mg/m-m propranolol',
#     'start': '2026-01-19',
#     'end': 'Ongoing'},
#    {'name': 'Lactulose',
#     'dose': '30ml',
#     'route': 'Oral',
#     'frequency': 'three times daily',
#     'start': '2025-10-19',
#     'end': '2026-01-18'},
#    {'name': 'Furosemide',
#     'dose': '20mg',
#     'route': 'Oral',
#     'frequency': 'twice daily',
#     'start': '2025-10-19',
#     'end': '2026-01-18'},
#    {'name': 'Propranolol',
#     'dose': '40mg',
#     'route': 'Oral',
#     'frequency': 'twice daily',
#     'start': '2025-10-19',
#     'end': '2026-01-18'},
#    {'name': 'Sertraline',
#     'dose': '50mg',
#     'route': 'Oral',
#     'frequency': 'daily',
#     'start': '2025-10-19',
#     'end': '2026-01-18'},
#    {'name': 'Thiamine',
#     'dose': '100mg',
#     'route': 'Oral',
#     'frequency': 'daily',
#     'start': '2025-10-19',
#     'end': '2026-01-18'},
#    {'name': 'Folic Acid',
#     'dose': '5mg',
#     'route': 'Oral',
#     'frequency': 'daily',
#     'start': '2025-10-19',
#     'end': '2026-01-18'},
#    {'name': 'Lactulose',
#     'dose': '30ml',
#     'route': 'Oral',
#     'frequency': 'every 2-3 hours until bowel movements established, then titrate',
#     'start': '2025-07-19',
#     'end': '2025-10-18'},
#    {'name': 'Furosemide',
#     'dose': '40mg',
#     'route': 'IV',
#     'frequency': 'once',
#     'start': '2025-07-19',
#     'end': '2025-07-19'},
#    {'name': 'Furosemide',
#     'dose': '20mg',
#     'route': 'Oral',
#     'frequency': 'twice daily',
#     'start': '2025-07-19',
#     'end': '2025-10-18'},
#    {'name': 'Thiamine',
#     'dose': '100mg',
#     'route': 'IV',
#     'frequency': 'once',
#     'start': '2025-07-19',
#     'end': '2025-07-19'},
#    {'name': 'Thiamine',
#     'dose': '100mg',
#     'route': 'Oral',
#     'frequency': 'daily',
#     'start': '2025-07-19',
#     'end': '2025-10-18'},
#    {'name': 'Folic Acid',
#     'dose': '5mg',
#     'route': 'Oral',
#     'frequency': 'daily',
#     'start': '2025-07-19',
#     'end': '2025-10-18'}],
#   'allergies': [],
#   'id': 'sidebar-1',
#   'componentType': 'Sidebar',
#   'zone': 'adv-event-zone'},
#  {'description': 'Arthur Pendelton is a 54-year-old male presenting with decompensated alcoholic liver cirrhosis, experiencing worsening ascites, confusion, jaundice, and poor medication compliance with a recent alcohol relapse.',
#   'patient': {'name': 'Arthur Pendelton',
#    'date_of_birth': '1970-03-15',
#    'age': 55,
#    'sex': 'Male',
#    'identifiers': {'mrn': 'P0001'}},
#   'riskLevel': 'critical',
#   'primaryDiagnosis': 'Decompensated Alcoholic Liver Cirrhosis with Ascites and Hepatic Encephalopathy',
#   'problem_list': [{'name': 'Decompensated Alcoholic Liver Cirrhosis',
#     'status': 'active'},
#    {'name': 'Ascites', 'status': 'active'},
#    {'name': 'Hepatic Encephalopathy', 'status': 'active'},
#    {'name': 'Jaundice', 'status': 'active'},
#    {'name': 'Confusion', 'status': 'active'},
#    {'name': 'Alcohol Relapse', 'status': 'active'},
#    {'name': 'Poor Medication Compliance', 'status': 'active'},
#    {'name': 'Esophageal Varices', 'status': 'chronic'},
#    {'name': 'Depression', 'status': 'chronic'},
#    {'name': 'Ankle Swelling', 'status': 'active'},
#    {'name': 'Nausea', 'status': 'active'},
#    {'name': 'Poor Appetite', 'status': 'active'}],
#   'medication_timeline': [{'name': 'Lactulose',
#     'dose': '500 grg',
#     'route': 'Oral',
#     'frequency': 'to one other afculpating ascite (etre consly)',
#     'start': '2026-01-19',
#     'end': 'Ongoing'},
#    {'name': 'Furosemide',
#     'dose': '200 grg',
#     'route': 'Oral',
#     'frequency': 'as-nzety 400 mg/for 1tiz.m in morteh',
#     'start': '2026-01-19',
#     'end': 'Ongoing'},
#    {'name': 'Propranolol',
#     'dose': '100 grg',
#     'route': 'Oral',
#     'frequency': 'da-apsity 300 mg/m-m propranolol',
#     'start': '2026-01-19',
#     'end': 'Ongoing'},
#    {'name': 'Lactulose',
#     'dose': '30ml',
#     'route': 'Oral',
#     'frequency': 'three times daily',
#     'start': '2025-10-19',
#     'end': '2026-01-18'},
#    {'name': 'Furosemide',
#     'dose': '20mg',
#     'route': 'Oral',
#     'frequency': 'twice daily',
#     'start': '2025-10-19',
#     'end': '2026-01-18'},
#    {'name': 'Propranolol',
#     'dose': '40mg',
#     'route': 'Oral',
#     'frequency': 'twice daily',
#     'start': '2025-10-19',
#     'end': '2026-01-18'},
#    {'name': 'Sertraline',
#     'dose': '50mg',
#     'route': 'Oral',
#     'frequency': 'daily',
#     'start': '2025-10-19',
#     'end': '2026-01-18'},
#    {'name': 'Thiamine',
#     'dose': '100mg',
#     'route': 'Oral',
#     'frequency': 'daily',
#     'start': '2025-10-19',
#     'end': '2026-01-18'},
#    {'name': 'Folic Acid',
#     'dose': '5mg',
#     'route': 'Oral',
#     'frequency': 'daily',
#     'start': '2025-10-19',
#     'end': '2026-01-18'},
#    {'name': 'Lactulose',
#     'dose': '30ml',
#     'route': 'Oral',
#     'frequency': 'every 2-3 hours until bowel movements established, then titrate',
#     'start': '2025-07-19',
#     'end': '2025-10-18'},
#    {'name': 'Furosemide',
#     'dose': '40mg',
#     'route': 'IV',
#     'frequency': 'once',
#     'start': '2025-07-19',
#     'end': '2025-07-19'},
#    {'name': 'Furosemide',
#     'dose': '20mg',
#     'route': 'Oral',
#     'frequency': 'twice daily',
#     'start': '2025-07-19',
#     'end': '2025-10-18'},
#    {'name': 'Thiamine',
#     'dose': '100mg',
#     'route': 'IV',
#     'frequency': 'once',
#     'start': '2025-07-19',
#     'end': '2025-07-19'},
#    {'name': 'Thiamine',
#     'dose': '100mg',
#     'route': 'Oral',
#     'frequency': 'daily',
#     'start': '2025-07-19',
#     'end': '2025-10-18'},
#    {'name': 'Folic Acid',
#     'dose': '5mg',
#     'route': 'Oral',
#     'frequency': 'daily',
#     'start': '2025-07-19',
#     'end': '2025-10-18'}],
#   'allergies': [],
#   'id': 'sidebar-1',
#   'componentType': 'Sidebar',
#   'zone': 'adv-event-zone'},
#  {'id': 'raw-encounter-image-1',
#   'imageUrl': 'patient_data_P0001_raw_data_encounter_report_0_2026-01-19.png',
#   'componentType': 'RadiologyImage',
#   'zone': 'raw-ehr-data-zone'},
#  {'id': 'raw-encounter-image-2',
#   'imageUrl': 'patient_data_P0001_raw_data_encounter_report_1_2025-10-19.png',
#   'componentType': 'RadiologyImage',
#   'zone': 'raw-ehr-data-zone'},
#  {'id': 'raw-encounter-image-3',
#   'imageUrl': 'patient_data_P0001_raw_data_encounter_report_2_2025-07-19.png',
#   'componentType': 'RadiologyImage',
#   'zone': 'raw-ehr-data-zone'},
#  {'id': 'raw-lab-image-radiology-1',
#   'imageUrl': 'patient_data_P0001_raw_data_imaging_report_0_2026-01-19.png',
#   'componentType': 'RadiologyImage',
#   'zone': 'raw-ehr-data-zone'},
#  {'id': 'raw-lab-image-radiology-2',
#   'imageUrl': 'patient_data_P0001_raw_data_imaging_report_2_2025-07-19.png',
#   'componentType': 'RadiologyImage',
#   'zone': 'raw-ehr-data-zone'},
#  {'id': 'raw-lab-image-1',
#   'imageUrl': 'patient_data_P0001_raw_data_lab_report_0_2025-07-19.png',
#   'componentType': 'RadiologyImage',
#   'zone': 'raw-ehr-data-zone'},
#  {'id': 'raw-lab-image-2',
#   'imageUrl': 'patient_data_P0001_raw_data_lab_report_1_2025-10-19.png',
#   'componentType': 'RadiologyImage',
#   'zone': 'raw-ehr-data-zone'},
#  {'id': 'raw-lab-image-3',
#   'imageUrl': 'patient_data_P0001_raw_data_lab_report_2_2026-01-19.png',
#   'componentType': 'RadiologyImage',
#   'zone': 'raw-ehr-data-zone'},
#  {'id': 'referral-doctor-info',
#   'date': '2026-01-20',
#   'visitType': 'Referred By',
#   'provider': 'Dr. Anya Sharma, MBBS, MRCGP',
#   'specialty': 'General Practice',
#   'rawText': 'HIGH STREET MEDICAL PRACTICE\n100 High St, Manchester, UK\nTel: 0161 123 4567\nDate: 20 Jan 2026\nTo: The Hepatology Registrar\nManchester Royal Infirmary\nOxford Road\nManchester\nM13 9WL\nRE. URGENT REFERRAL\nPATIENT: Arthur Pendelton\nDOB: 15/03/1970\nAddress: 12 Eim Street, Manchester, M14 5XX\nDear Colleague,\nThank you for seeing Mr. Pendelton, a 54-year-old male with a known history of alcoholic liver cirrhosis\n(Child-Pugh B), who presented to my clinic today with a significant relapse of his symptoms.\nIntroduction:\nMr. Pendelton is a 54-year-old male with a background of alcoholic liver cirrhosis (diagnosed 5 years\nago, Child-Pugh B), esophageal varices (status post endoscopic band ligation 2 years ago), and\nintermittent depression.\nCurrent Issue:\nMr. Pendelton presented today reporting a rapid return of significant abdominal distension over the\npast week, describing his abdomen as being "swellen up like a balleon." He has also experienced a\nrecurrence of confusion and forgetfulness, stating his "brain\'s gone all fuzzy." He admits to a relapse\nin his alcohol consumption over the last two weeks, averaging approximately 8-10 units per day.\nand has found it difficult to stop. He reports nausea, poor appetite, and a retum of ankle swelling.\nHe has not been taking his prescribed Lactulose regularly due to its laxative effect and has missed\ndoses of Furosemide and Propranolol.\nOn examination today, he appeared unwell with visible jaundice and a distended, tense abdomen.\nVital signs revealed mild hypotension (BP 100/65 mmHg) and tachycardia (HR 100 bpm). Physical\nexamination confirmed marked abdominal distension with a positive fluid wave and shifting dullness,\nindicative of significant ascites. Bilateral pitting edema was noted up to his mid-shin.\nBackground:\nMr. Pendelton\'s chronic conditions include alcoholic liver cirrhosis, esophageal varices, and\ndepression. His medication compliance has historically been poor, particularly with Lactulose and\nSertraline. He has a history of heavy alcohol consumption for approximately 20 years, averaging 60\nunits per week, and has recently relapsed.\nAction:\nGiven the acute decompensation with ascites and hepatic encephalopathy, likely secondary to poor\nmedication compliance and recent alcohol relapse, I believe Mr. Pendelton requires urgent\nassessment and management. I have advised him to attend the Acute Medical Assessment Unit\nimmediately. I have provided him with this letter and requested urgent blood tests including CBC,\nLFTs, Urea & Electrolytes, and a coagulation screen.\nI would appreciate your urgent assessment and management of Mr. Pendelton\'s decompensated\ncimhosis, including consideration for hospital admission and management of his alcohol relapse and\nmedication compliance.\nSincerely,\nDr. Anya Sharma, MBBS, MRCGP\nAnya Sharma',
#   'dataSource': 'HIGH STREET MEDICAL PRACTICE',
#   'highlights': ['Date: 20 Jan 2026',
#    'URGENT REFERRAL',
#    'alcoholic liver cirrhosis',
#    'significant relapse of his symptoms',
#    'acute decompensation with ascites and hepatic encephalopathy',
#    'urgent assessment and management',
#    'Dr. Anya Sharma, MBBS, MRCGP'],
#   'componentType': 'RawClinicalNote',
#   'zone': 'referral-zone'},
#  {'id': 'referral-letter-image',
#   'date': '2026-01-20',
#   'studyType': 'Urgent Referral',
#   'provider': 'Dr. Anya Sharma, MBBS, MRCGP',
#   'specialty': 'General Practice',
#   'imageUrl': '',
#   'dataSource': 'HIGH STREET MEDICAL PRACTICE',
#   'componentType': 'RadiologyImage',
#   'zone': 'referral-zone'}]

# %%
data = response.json()
counter = 0
for d in data:
    if "zone" in d:
        counter = counter + 1

counter
# Out:
# 24

# %%
import requests

BASE_URL = "http://localhost:8000"

endpoint = f"{BASE_URL}/patients"

response = requests.get(endpoint)
response.json()
# Out:
# [{'patient_id': 'P0001',
#   'name': 'Arthur Pendelton',
#   'firstName': 'Arthur',
#   'lastName': 'Pendelton',
#   'dob': '1970-03-15',
#   'age': 54,
#   'gender': 'Male',
#   'occupation': 'Former Bricklayer, Unemployed',
#   'maritalStatus': 'Unknown',
#   'biometrics': {'height_cm': 175, 'weight_kg': 85, 'bmi': 27.8},
#   'contact': {'phone': '+44 7700 900123',
#    'email': 'arthur.pendelton@example.com',
#    'address': {'street': '10 Downing Street',
#     'city': 'Manchester',
#     'state': 'Greater Manchester',
#     'zipCode': 'M1 1AA'},
#    'emergency': {'name': 'Eleanor Pendelton',
#     'relation': 'Sister',
#     'phone': '+44 7700 900456'}},
#   'complaint': 'Massive abdominal swelling, confusion, and jaundice.',
#   'medical_history': ['Alcoholic Liver Cirrhosis (diagnosed 5 years ago, Child-Pugh B)',
#    'Esophageal Varices (status post endoscopic band ligation 2 years ago)',
#    'Major Depressive Disorder (diagnosed 10 years ago)',
#    'Appendectomy (childhood)'],
#   'social_history': {'smoking_status': 'Former smoker (15 pack-years, quit 10 years ago)',
#    'alcohol_consumption': 'Heavy alcohol consumption (~60 units/week for 20 years), recent relapse.'},
#   'allergies': ['No Known Drug Allergies'],
#   'description': '54-year-old Male presenting with abdominal swelling, confusion, and jaundice.',
#   'severity': 'Critical'},
#  {'patient_id': 'P0002',
#   'name': 'Eleanor Vance',
#   'firstName': 'Eleanor',
#   'lastName': 'Vance',
#   'dob': '1962-05-15',
#   'age': 62,
#   'gender': 'Female',
#   'occupation': 'Retired School Administrator',
#   'maritalStatus': 'Married',
#   'biometrics': {'height_cm': 163, 'weight_kg': 75, 'bmi': 28.2},
#   'contact': {'phone': '+44 7700 900123',
#    'email': 'eleanor.vance@example.com',
#    'address': {'street': '15 Oak Avenue',
#     'city': 'Leeds',
#     'state': 'West Yorkshire',
#     'zipCode': 'LS16 6XX'},
#    'emergency': {'name': 'Arthur Vance',
#     'relation': 'Husband',
#     'phone': '+44 7700 900124'}},
#   'complaint': 'Progressive abdominal bloating, increasing fatigue, easy bruising, and mild shortness of breath when lying flat.',
#   'medical_history': ['NASH-related Liver Cirrhosis (Child-Pugh A progressing to B)',
#    'Type 2 Diabetes Mellitus (diagnosed 10 years ago)',
#    'Hypertension (diagnosed 15 years ago)',
#    'Hyperlipidaemia (diagnosed 15 years ago)',
#    'Appendectomy (age 22)',
#    'Cholecystectomy (age 55)'],
#   'social_history': {'smoking_status': 'Never Smoked',
#    'alcohol_consumption': 'Minimal (1-2 units of wine per week)'},
#   'allergies': ['Penicillin (rash)'],
#   'description': '62-year-old Female presenting with progressive abdominal bloating and fatigue due to NASH-related cirrhosis.',
#   'severity': 'High'}]

# %%
response.status_code
# Out:
# 500

# %%
import requests

BASE_URL = "http://localhost:8000"

endpoint = f"{BASE_URL}/data/P0001/board_objects.json"

response = requests.get(endpoint)
board_data = response.json()
board_data

with open(f"output/board_data_pipeline.json", "w", encoding="utf-8") as f:
    json.dump(board_data, f, indent=4)

# %%
len(board_data)
missed = []
for b in board_data:
    if 'componentType' not in b:
        missed.append(b['id'])

# %%
missed
# Out:
# []

# %%
import requests

BASE_URL = "http://localhost:8000"

endpoint = f"{BASE_URL}/process/P0001/board-update"

response = requests.get(endpoint)
board_data = response.json()
board_data

# with open(f"output/board_data_pipeline.json", "w", encoding="utf-8") as f:
#     json.dump(board_data, f, indent=4)
# Out:
# {'status': 'success', 'message': 'Board objects have been processed.'}

# %%
import requests

BASE_URL = "http://localhost:8000"
PATIENT_ID = "P0001"  # <--- REPLACE THIS with an actual ID from your generation step

endpoint = f"{BASE_URL}/chat/{PATIENT_ID}/reset"

response = requests.post(endpoint, json={"patient_id": PATIENT_ID})
response.json()
# Out:
# {'status': 'success',
#  'message': 'Chat history has been reset.',
#  'current_state': {'conversation': [{'sender': 'admin',
#     'message': 'Hello, this is Linda the Hepatology Clinic admin desk. How can I help you today?'}]}}

# %%
import requests

BASE_URL = "https://clinic-sim-pipeline-481780815788.europe-west1.run.app"
PATIENT_ID = "P0001"  # <--- REPLACE THIS with an actual ID from your generation step

endpoint = f"{BASE_URL}/chat/{PATIENT_ID}"

response = requests.get(endpoint)
response.json()
# Out:
# {'conversation': [{'sender': 'admin',
#    'message': 'Hello, this is Linda the Hepatology Clinic admin desk. How can I help you today?'},
#   {'sender': 'patient', 'message': 'hi', 'attachments': [], 'form_data': {}},
#   {'message': 'Hello, this is Linda the Hepatology Clinic admin desk. Have you booked an appointment through the NHS App?',
#    'action_type': 'TEXT_ONLY',
#    'sender': 'admin'},
#   {'sender': 'patient', 'message': 'nope', 'attachments': [], 'form_data': {}},
#   {'message': 'Thank you. Please confirm your details in this form.',
#    'action_type': 'SEND_FORM',
#    'form_request': {'name': '',
#     'firstName': '',
#     'lastName': '',
#     'dob': '',
#     'age': None,
#     'gender': '',
#     'occupation': '',
#     'maritalStatus': '',
#     'contact': {'phone': '',
#      'email': '',
#      'address': {'street': '', 'city': '', 'state': '', 'zipCode': ''},
#      'emergency': {'name': '', 'relation': '', 'phone': ''}},
#     'complaint': '',
#     'medical_history': [],
#     'allergies': []},
#    'sender': 'admin'},
#   {'sender': 'patient',
#    'message': 'I have completed the intake form.',
#    'attachments': [],
#    'form_data': {'name': 'Arthur',
#     'dob': '1970-03-15',
#     'contact': {'phone': '+44 7700 901234',
#      'email': 'arthur.pendelton70@example.com',
#      'address': {'street': '14 Ashton Court, Flat 2A, Manchester',
#       'city': 'London',
#       'state': 'UK',
#       'zipCode': ''},
#      'emergency': {'name': '', 'relation': '', 'phone': ''}},
#     'complaint': 'Progressive abdominal swelling, jaundice, confusion, and ankle swelling',
#     'medical_history': [],
#     'allergies': []}},
#   {'message': 'Thank you for the details. To help the doctor prepare, do you have recent blood test results?',
#    'action_type': 'TEXT_ONLY',
#    'sender': 'admin'},
#   {'sender': 'patient',
#    'message': 'I have completed the intake form.',
#    'attachments': [],
#    'form_data': {'name': 'test',
#     'dob': '1',
#     'gender': 'test',
#     'occupation': 'test',
#     'contact': {'phone': '1279',
#      'email': 'test@m.com',
#      'address': {'street': '18 n',
#       'city': 'London',
#       'state': 'UK',
#       'zipCode': ''},
#      'emergency': {'name': '', 'relation': '', 'phone': ''}},
#     'complaint': 'hsa',
#     'medical_history': [],
#     'allergies': []}},
#   {'message': 'Do you have any radiology reports (Ultrasound/CT/MRI)?',
#    'action_type': 'TEXT_ONLY',
#    'sender': 'admin'},
#   {'sender': 'patient',
#    'message': 'This is the latest one',
#    'attachments': ['lab_report_chat_test.png'],
#    'form_data': None},
#   {'message': 'Do you have the GP Referral Letter?',
#    'action_type': 'TEXT_ONLY',
#    'sender': 'admin'},
#   {'sender': 'patient',
#    'message': 'No I dont have the referral',
#    'attachments': [],
#    'form_data': None},
#   {'message': 'Thank you for providing those documents. I have added them to your file. Dr. Gupta has these urgent slots available:',
#    'action_type': 'OFFER_SLOTS',
#    'available_slots': {'doctorName': 'Dr. A. Gupta',
#     'specialty': 'Hepatology',
#     'slots': [{'slotId': 'SLOT_10_AM',
#       'date': '2025-12-10',
#       'time': '09:30 AM',
#       'type': 'In-Person'},
#      {'slotId': 'SLOT_11_PM',
#       'date': '2025-12-11',
#       'time': '02:00 PM',
#       'type': 'In-Person'},
#      {'slotId': 'SLOT_12_AM',
#       'date': '2025-12-12',
#       'time': '10:00 AM',
#       'type': 'In-Person'}]},
#    'sender': 'admin'},
#   {'sender': 'patient',
#    'message': 'I will take the slot on 2025-12-10 at 09:30 AM.',
#    'attachments': [],
#    'form_data': None},
#   {'message': 'Confirmed. Here are your details. Please arrive 15 minutes early.',
#    'action_type': 'CONFIRM_APPOINTMENT',
#    'confirmed_appointment': {'appointmentId': 'APT-HEP-78321',
#     'status': 'Confirmed',
#     'schedule': {'date': '2025-12-10',
#      'time': '09:30 AM',
#      'provider': 'Dr. A. Gupta',
#      'location': 'Hepatology Clinic',
#      'instructions': 'Please arrive 15 minutes prior to your appointment.'}},
#    'sender': 'admin'}]}

# %%
import requests
import json
import sys

# Configuration
BASE_URL = "http://localhost:8000"
# REPLACE with a patient_id that actually exists in your data
DEFAULT_PATIENT_ID = "P0001" 
DEFAULT_MESSAGE = "Hello, I would like to book an appointment with the hepatologist."

def test_send_message(patient_id, message):
    endpoint = f"{BASE_URL}/chat"
    
    payload = {
        "patient_id": patient_id,
        "patient_message": message
    }

    print(f"🔵 sending POST request to: {endpoint}")
    print(f"📤 Payload: {json.dumps(payload, indent=2)}")
    print("-" * 40)

    try:
        response = requests.post(endpoint, json=payload)
        
        # Check success
        if response.status_code == 200:
            return response
            
        elif response.status_code == 404:
            print("❌ FAILED (404 Not Found)")
            print(f"Reason: {response.json().get('detail')}")
            print("Hint: This usually means the patient_id folder or chat history file doesn't exist yet.")
            
        else:
            print(f"❌ FAILED ({response.status_code})")
            print(response.text)

    except requests.exceptions.ConnectionError:
        print("❌ CRITICAL ERROR: Could not connect to server.")
        print("Is the server running? Try: python server.py")


    
response_chat = test_send_message(DEFAULT_PATIENT_ID, DEFAULT_MESSAGE)
# Out:
# 🔵 sending POST request to: http://localhost:8000/chat
# 📤 Payload: {
#   "patient_id": "P0001",
#   "patient_message": "What is the available schedule for the hepatologist?"
# }
# ----------------------------------------

# %%
response_chat.json()
# Out:
# {'patient_id': 'P0001',
#  'nurse_response': {'message': 'Thanks. Here are the available slots for Dr. A. Gupta.',
#   'action_type': 'OFFER_SLOTS',
#   'available_slots': {'doctorName': 'Dr. A. Gupta',
#    'specialty': 'Hepatology',
#    'slots': [{'slotId': 'SLOT_10_AM',
#      'date': '2025-12-10',
#      'time': '09:30 AM',
#      'type': 'In-Person'},
#     {'slotId': 'SLOT_11_PM',
#      'date': '2025-12-11',
#      'time': '02:00 PM',
#      'type': 'In-Person'},
#     {'slotId': 'SLOT_12_AM',
#      'date': '2025-12-12',
#      'time': '10:00 AM',
#      'type': 'In-Person'}]}},
#  'status': 'success'}

# %%
raw_data = json.loads(gcs.read_file_as_string(f"patient_data/P0001/raw_data.json"))
raw_data
# Out:
# {'encounter_reports': [{'file': 'encounter_report_0_2026-01-19.txt',
#    'date_time': '2026-01-19',
#    'encounter_report_text': '   SPRINGFIELD FAMILY CLINIC - URGENT CARE\n   456 Health Avenue, Springfield\n   ----------------------------------------\n   VISIT SUMMARY REPORT\n   Date: 2026-01-19\n\n   PATIENT: Arthur Pendelton (Male, 54)\n   ID: #003\n\n   REASON FOR VISIT:\n   Return of ascites, confusion, and poor medication compliance with recent alcohol relapse.\n\n   CLINICAL NOTES:\n   Patient presents to his GP feeling significantly unwell, reporting a return of his abdominal distension over the past week, stating his trousers are "too tight again." He also notes increased episodes of confusion and forgetfulness, describing it as "my brain\'s gone all fuzzy." He admits to relapsing into heavier alcohol consumption over the last two weeks, averaging around 8-10 units per day, finding it difficult to stop. He reports feeling nauseous and has had a poor appetite. He hasn\'t been taking his Lactulose regularly because "it makes me run to the loo too much." He has also missed several doses of his Furosemide and Propranolol. He denies any chest pain, shortness of breath, or fever. General appearance is unwell, with a distended abdomen and a yellow tinge to his skin. He seems slightly disoriented and speaks slowly. Abdomen is markedly distended, tense, with positive fluid wave and shifting dullness. Mild diffuse tenderness. Lungs clear, diminished breath sounds at bases. Cardiovascular is tachycardic, regular rhythm. Extremities show bilateral pitting edema up to mid-shin.\n\n   DIAGNOSIS:\n   Decompensated Alcoholic Liver Cirrhosis with Ascites and Hepatic Encephalopathy\n\n   TREATMENT PLAN:\n   - Investigations: CBC, LFTs, Urea & Electrolytes, Coagulation screen (PT/INR). Abdominal ultrasound to consider.\n   - Medications:\n     - Lactulose 30ml Oral three times daily for Hepatic encephalopathy.\n     - Furosemide 20mg Oral twice daily for Ascites.\n     - Propranolol 40mg Oral twice daily for Portal hypertension/varices prophylaxis.\n   - Management: Advised Arthur that his symptoms are concerning and he needs to be reviewed urgently by the hospital team. Provided a letter of referral to the local hospital\'s Acute Medical Assessment Unit. Strongly advised him to attend immediately for further assessment and potential admission. Discussed the risks of his current alcohol intake and poor compliance. Offered support services for alcohol cessation. Urgent review by hospital team.\n\n   ----------------------------------------\n   Signed,\n   Dr. Anya Sharma, General Practitioner'},
#   {'file': 'encounter_report_1_2025-10-19.txt',
#    'date_time': '2025-10-19',
#    'encounter_report_text': '   SPRINGFIELD GASTROENTEROLOGY CLINIC\n   456 Digestive Lane, Springfield\n   ----------------------------------------\n   VISIT SUMMARY REPORT\n   Date: 2025-10-19\n\n   PATIENT: Arthur Pendelton (Male, 54)\n   ID: #2\n\n   REASON FOR VISIT:\n   Follow-up after hospital admission for decompensated alcoholic liver cirrhosis.\n\n   CLINICAL NOTES:\n   Patient presents for scheduled follow-up. He reports improved abdominal distension and reduced confusion since his recent admission for decompensated alcoholic liver cirrhosis. He states he has been taking Lactulose inconsistently and has reduced alcohol intake to 2-3 units per day, with occasional slip-ups. He still experiences fatigue and poor appetite but feels generally better. He has been compliant with Furosemide and has noticed reduced ankle swelling. Physical exam reveals improved alertness and less jaundice. Abdomen is mildly distended with trace pitting edema at the ankles.\n\n   DIAGNOSIS:\n   Stable Alcoholic Liver Cirrhosis, improved from decompensation. Continued risk of decompensation with continued alcohol use.\n\n   TREATMENT PLAN:\n   Labs: Liver Function Tests (LFTs), CBC, Electrolytes, Renal Function.\n   Medications:\n   - Lactulose 30ml Oral three times daily for Hepatic encephalopathy.\n   - Furosemide 20mg Oral twice daily for Ascites.\n   - Propranolol 40mg Oral twice daily for Portal hypertension/varices prophylaxis.\n   - Sertraline 50mg Oral daily for Depression.\n   - Thiamine 100mg Oral daily for Alcoholic liver disease.\n   - Folic Acid 5mg Oral daily for Alcoholic liver disease.\n   Instructions: Continue strict alcohol abstinence. Aim for a low-sodium diet. Emphasized importance of regular medication compliance.\n   Follow-up: Regular clinic appointments every 4 weeks. Discussed potential need for repeat variceal banding if indicated.\n\n   ----------------------------------------\n   Signed,\n   Dr. Eleanor Vance, Gastroenterologist'},
#   {'file': 'encounter_report_2_2025-07-19.txt',
#    'date_time': '2025-07-19',
#    'encounter_report_text': '   CITY GENERAL HOSPITAL - EMERGENCY DEPT\n   123 Main Street, Metropolis\n   ----------------------------------------\n   VISIT SUMMARY REPORT\n   Date: 2025-07-19\n\n   PATIENT: Arthur Pendelton (Male, 54)\n\n   REASON FOR VISIT:\n   Progressive abdominal distension, jaundice, confusion, and ankle swelling.\n\n   CLINICAL NOTES:\n   Patient presents with a 2-3 week history of progressive abdominal distension, jaundice noted for one week, and increasing confusion, forgetfulness, and difficulty concentrating over the last few days. He also reports significant bilateral ankle swelling, fatigue, and nausea. Patient admits to recent relapse in alcohol consumption. Physical exam reveals jaundice, marked abdominal distension with ascites, bilateral pitting edema, and disorientation with asterixis.\n\n   DIAGNOSIS:\n   Decompensated Alcoholic Liver Cirrhosis with Ascites and Hepatic Encephalopathy\n\n   TREATMENT PLAN:\n   - Admission to the General Medical ward.\n   - Strict fluid balance monitoring and low sodium diet.\n   - Strict alcohol abstinence to be enforced.\n   - Regular neurological checks.\n   - Medications Started:\n     - Lactulose 30ml Oral every 2-3 hours until bowel movements established, then titrate.\n     - Furosemide 40mg IV once, then 20mg orally twice daily.\n     - Normal Saline 75 ml/hr IV continuous.\n     - Thiamine 100mg IV once, then 100mg orally daily.\n     - Folic Acid 5mg Oral daily.\n   - Investigations: CBC, CMP, Coags, Blood cultures, UA, Abdominal Ultrasound, Chest X-ray.\n\n   ----------------------------------------\n   Signed,\n   Dr. Eleanor Vance, Gastroenterologist'}],
#  'lab_reports': [{'file': 'lab_report_0_2025-07-19.txt',
#    'date_time': '2025-07-19T00:00:00Z',
#    'lab_report_text': '```text\n   ----------------------------------------------------------------------\n   DEPARTMENT OF PATHOLOGY & LABORATORY MEDICINE\n   Lab ID: #12345678\n   ----------------------------------------------------------------------\n   PATIENT: Arthur Pendelton\n   COLLECTED: 19 Jul 2025\n   ----------------------------------------------------------------------\n   TEST NAME                     RESULT    UNIT      REF. RANGE     FLAG\n   ----------------------------------------------------------------------\n   White Blood Cell Count        8.5       10^3/uL   3.4 - 10.8     -\n   Hemoglobin                    10.5      g/dL      13.5 - 17.5    *LOW*\n   Platelets                     130.0     10^3/uL   150.0 - 450.0  *LOW*\n   AST                           120.0     U/L       10.0 - 40.0    *HIGH*\n   ALT                           95.0      U/L       7.0 - 56.0     *HIGH*\n   Total Bilirubin               5.5       mg/dL     0.2 - 1.2      *HIGH*\n   Albumin                       2.4       g/dL      3.4 - 5.4      *LOW*\n   Prothrombin Time (PT) / INR   1.9       INR       0.9 - 1.1      *HIGH*\n   Sodium                        133.0     mmol/L    135.0 - 145.0  *LOW*\n   Potassium                     4.2       mmol/L    3.5 - 5.0      -\n   Creatinine                    1.1       mg/dL     0.6 - 1.2      -\n   ----------------------------------------------------------------------\n   Verified by: AutoAnalyzer / Pathologist on Call\n```'},
#   {'file': 'lab_report_1_2025-10-19.txt',
#    'date_time': '2025-10-19T00:00:00Z',
#    'lab_report_text': '```text\n   ----------------------------------------------------------------------\n   DEPARTMENT OF PATHOLOGY & LABORATORY MEDICINE\n   Patient Name: Arthur Pendelton\n   Collection Date: 19 Oct 2025\n   Lab ID: #12345678\n   ----------------------------------------------------------------------\n\n   ----------------------------------------------------------------------\n   TEST NAME                     RESULT    UNIT      REF. RANGE     FLAG\n   ----------------------------------------------------------------------\n   White Blood Cell Count        7.2       10^3/uL   3.4 - 10.8     -\n   Hemoglobin                    11.8      g/dL      13.5 - 17.5    *LOW*\n   Platelets                     145.0     10^3/uL   150.0 - 450.0  *LOW*\n   AST                           75.0      U/L       10.0 - 40.0    *HIGH*\n   ALT                           60.0      U/L       7.0 - 56.0     *HIGH*\n   Total Bilirubin               2.1       mg/dL     0.2 - 1.2      *HIGH*\n   Albumin                       2.9       g/dL      3.4 - 5.4      *LOW*\n   Prothrombin Time (PT) / INR   1.4       INR       0.9 - 1.1      *HIGH*\n   Sodium                        138.0     mmol/L    135.0 - 145.0  -\n   Potassium                     4.0       mmol/L    3.5 - 5.0      -\n   Creatinine                    0.9       mg/dL     0.6 - 1.2      -\n   ----------------------------------------------------------------------\n   Verified by: AutoAnalyzer / Pathologist on Call\n   ----------------------------------------------------------------------\n```'},
#   {'file': 'lab_report_2_2026-01-19.txt',
#    'date_time': '2026-01-19T00:00:00Z',
#    'lab_report_text': '```text\n   ----------------------------------------------------------------------\n   DEPARTMENT OF PATHOLOGY & LABORATORY MEDICINE\n   Patient Name: Arthur Pendelton\n   Collection Date: 19 Jan 2026\n   Lab ID: #12345678\n   ----------------------------------------------------------------------\n\n   ----------------------------------------------------------------------\n   TEST NAME                     RESULT    UNIT      REF. RANGE     FLAG\n   ----------------------------------------------------------------------\n   White Blood Cell Count        9.8       10^3/uL   3.4 - 10.8     -\n   Hemoglobin                    10.2      g/dL      13.5 - 17.5    *LOW*\n   Platelets                     125.0     10^3/uL   150.0 - 450.0  *LOW*\n   AST                           150.0     U/L       10.0 - 40.0    *HIGH*\n   ALT                           110.0     U/L       7.0 - 56.0     *HIGH*\n   Total Bilirubin               6.8       mg/dL     0.2 - 1.2      *HIGH*\n   Albumin                       2.2       g/dL      3.4 - 5.4      *LOW*\n   Prothrombin Time (PT) / INR   2.1       INR       0.9 - 1.1      *HIGH*\n   Sodium                        132.0     mmol/L    135.0 - 145.0  *LOW*\n   Potassium                     4.5       mmol/L    3.5 - 5.0      -\n   Creatinine                    1.3       mg/dL     0.6 - 1.2      *HIGH*\n   ----------------------------------------------------------------------\n   Verified by: AutoAnalyzer / Pathologist on Call\n   ----------------------------------------------------------------------\n```'}],
#  'imaging_reports': [{'file': 'imaging_report_0_2026-01-19.txt',
#    'date_time': '2026-01-19',
#    'imaging_report_text': '```text\n   DEPARTMENT OF RADIOLOGY\n   --------------------------------------------------------\n   PATIENT: Arthur Pendelton\n   EXAM: Abdominal Ultrasound\n   DATE: October 26, 2023\n   --------------------------------------------------------\n   INDICATION: Patient presents with abdominal distension, altered mental status, and history of alcohol abuse, concerning for decompensated liver disease.\n   \n    [[IMAGE_PROMPT: A realistic, high-contrast black and white abdominal ultrasound image. The liver appears shrunken and irregularly bordered with a coarse echotexture. Multiple hypoechoic (darker) areas are seen within the liver parenchyma. The spleen is enlarged and hypoechoic. A significant amount of anechoic (black) fluid is seen filling the peritoneal cavity, outlining the bowel loops. The portal vein appears patent but possibly narrowed.]]\n\n\n   FINDINGS:\n   The liver is significantly reduced in size with an irregular, nodular contour and diffusely increased echogenicity, consistent with chronic changes. The hepatic parenchyma demonstrates a coarse and heterogeneous echotexture. The spleen is enlarged, measuring approximately 15 cm in craniocaudal dimension. A large volume of anechoic fluid is present throughout the peritoneal cavity, consistent with significant ascites. The bowel loops are diffusely thickened and appear to be floating within the ascites. The portal vein is visualized and appears patent, though its caliber may be reduced. The gallbladder is unremarkable. The kidneys are normal in size and echogenicity. No focal intra-abdominal masses are identified.\n   \n   IMPRESSION:\n   Findings are highly suggestive of decompensated alcoholic liver cirrhosis with significant ascites. Splenomegaly is also noted. The findings are consistent with the clinical suspicion of hepatic encephalopathy secondary to liver dysfunction.\n   \n   --------------------------------------------------------\n   Signed:\n   Dr. A. Ray, MD (Radiology)\n```'},
#   {'file': 'imaging_report_2_2025-07-19.txt',
#    'date_time': '2025-07-19',
#    'imaging_report_text': "```text\n   DEPARTMENT OF RADIOLOGY\n   --------------------------------------------------------\n   PATIENT: Arthur Pendelton\n   EXAM: Chest X-ray\n   DATE: October 26, 2023\n   --------------------------------------------------------\n   INDICATION: Me belly's massive, looks like I'm gonna burst. And I'm feelin' proper confused, like I'm not myself. My eyes have gone yellow too. Patient presents with abdominal distension and altered mental status, concerning for decompensated liver disease.\n\n\n   [[IMAGE_PROMPT: A realistic, high-contrast black and white AP portable Chest X-ray. The image shows the thoracic cavity. There is a significant amount of free fluid in the abdominal cavity, causing a large, rounded contour to the abdomen that obscures the normal diaphragmatic domes and costophrenic angles. The lung fields appear clear, with no focal consolidation or pleural effusion. The heart size is normal. The bones appear bright white.]]\n\n\n   FINDINGS:\n   The cardiomediastinal silhouette is within normal limits. The lung fields are clear bilaterally, with no evidence of focal consolidation, pleural effusion, or pneumothorax. The visualized portions of the diaphragm are elevated and obscured by significant abdominal distension. There is evidence of moderate ascites, as suggested by the generalized abdominal fullness and blunting of the costophrenic angles due to fluid in the peritoneal cavity. No free air is identified beneath the diaphragm. The visualized bones are unremarkable.\n   \n   IMPRESSION:\n   Findings are suggestive of significant ascites, consistent with the clinical presentation of decompensated liver disease. No acute cardiopulmonary process identified.\n   \n   --------------------------------------------------------\n   Signed:\n   Dr. A. Ray, MD (Radiology)\n```"}]}

# %%
file_inventory = json.loads(gcs.read_file_as_string(f"patient_data/P0001/pre_consultation_chat.json"))

# %%
res = {
    "conversation" : [
            {
            'sender': 'admin',
            'message': 'Hello, this is Linda the Hepatology Clinic admin desk. How can I help you today?'
            }
    ]
}
gcs.create_file_from_string(json.dumps(res, indent=4), f"patient_data/P0001/pre_consultation_chat.json", content_type="application/json")

# %%
# Out:
# Content uploaded to patient_data/P0001/pre_consultation_chat.json.
# True

# %%
file_inventory
# Out:
# {'conversation': [{'sender': 'admin',
#    'message': 'Hello, thank you for contacting the General Hepatology Clinic. How can I help you today?'},
#   {'sender': 'patient',
#    'message': "Alright, I need to book an appointment with the specialist. I'm not feeling too good."},
#   {'sender': 'admin',
#    'message': 'I can help you with that. To confirm your identity, could you please provide your full name, date of birth, and current address?'},
#   {'sender': 'patient',
#    'message': 'Arthur Pendelton. Born 15th March 1970. I live at Flat 3, 12 Elm Street, Manchester.'},
#   {'sender': 'admin',
#    'message': "Thank you, Mr. Pendelton. Could you please describe your main symptoms and how long you've been experiencing them?"},
#   {'sender': 'patient',
#    'message': "Well, me belly's massive, looks like I'm gonna burst. And I'm feelin' proper confused, like I'm not myself. My eyes have gone yellow too. It's been getting worse for a few weeks now, especially the confusion, that's only been a few days."},
#   {'sender': 'admin',
#    'message': 'I understand. Have you noticed any other symptoms, such as swelling in your legs or ankles?'},
#   {'sender': 'patient',
#    'message': 'Yeah, my ankles are proper swollen, can barely get my shoes on.'},
#   {'sender': 'admin',
#    'message': 'Thank you for that information. Do you have any recent lab reports, imaging reports, or a referral letter from your GP that you can share with us?'},
#   {'sender': 'patient',
#    'message': "Yeah, I've got some bits here. Had a doctor's visit recently, they gave me a letter."},
#   {'sender': 'patient',
#    'message': "Here's the letter from the GP.",
#    'attachment': ['encounter_report_0_2026-01-19.txt']},
#   {'sender': 'admin',
#    'message': 'Thank you. Do you also have any recent blood test results?'},
#   {'sender': 'patient',
#    'message': 'Yes, I think these are from when I saw the doctor last.'},
#   {'sender': 'patient',
#    'message': 'Here they are.',
#    'attachment': ['lab_report_2_2026-01-19.txt']},
#   {'sender': 'admin',
#    'message': 'Thank you. And do you have any imaging reports, such as an ultrasound or X-ray?'},
#   {'sender': 'patient',
#    'message': 'I think there was an ultrasound done a while back, and maybe an X-ray.'},
#   {'sender': 'patient',
#    'message': "Here's the ultrasound.",
#    'attachment': ['imaging_report_0_2026-01-19.txt']},
#   {'sender': 'patient',
#    'message': 'And the X-ray.',
#    'attachment': ['imaging_report_2_2025-07-19.txt']},
#   {'sender': 'admin',
#    'message': 'Thank you, Mr. Pendelton. We have received all the necessary documents. Based on your symptoms and the information provided, we will schedule an urgent consultation with our specialist. You will receive a confirmation message with the appointment details shortly. Please ensure you follow any advice given by the specialist regarding your condition.'},
#   {'sender': 'patient',
#    'message': 'Alright, thanks. Just want to feel a bit better, like.'}]}

# %%
def group_labs_by_date(labs_data):

        grouped = {}

        for item in labs_data:
            # Extract static metadata for this biomarker
            biomarker_name = item.get("biomarker")
            unit = item.get("unit")
            ref_min = item.get("referenceRange", {}).get("min")
            ref_max = item.get("referenceRange", {}).get("max")

            # Iterate through the time-series values
            for measurement in item.get("values", []):
                timestamp = measurement.get("t")
                value = measurement.get("value")

                # Initialize the date group if it doesn't exist
                if timestamp not in grouped:
                    grouped[timestamp] = {
                        "date_time": timestamp,
                        "labs": []
                    }

                # Determine Flag (High/Low/Normal)
                flag = "NORMAL"
                if ref_min is not None and ref_max is not None:
                    if value < ref_min:
                        flag = "LOW"
                    elif value > ref_max:
                        flag = "HIGH"

                # Add this specific result to the group
                grouped[timestamp]["labs"].append({
                    "biomarker": biomarker_name,
                    "value": value,
                    "unit": unit,
                    "reference_range": f"{ref_min} - {ref_max}",
                    "flag": flag
                })

        # Convert dictionary to a list and sort by date (Newest last)
        # ISO 8601 dates (YYYY-MM-DD) sort correctly as strings
        sorted_results = sorted(list(grouped.values()), key=lambda x: x['date_time'])
        
        return sorted_results

# %%
with open("output/P0001/labs.json", "r", encoding="utf-8") as f:
    labs = json.load(f)

# %%
labs_data = group_labs_by_date(labs)

# %%
len(labs_data)
for i, lab_ in enumerate(labs_data):
    with open(f"output/P0001/lab{i+1}.json", "w", encoding="utf-8") as f:
        json.dump(lab_, f, indent=4)
